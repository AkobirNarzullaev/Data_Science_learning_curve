# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,40,43,39,45]

# %%
plt.title="Weather"
plt.xlabel='Day'
plt.ylabel='Temperature'
plt.plot(x,y, color='green', linewidth=5, linestyle='dashdot')

# %%
a = [1,2,3,4,5,6,7]
b = [33,60,55,43,42,35,40]

# %%
plt.plot(a,b, 'b+--')
