# %%
import pandas as pd
df = pd.read_csv('bukhara.csv')
df
# Out:
#        name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0   bukhara  2023-01-20      3.9    -10.1  -4.2           3.9         -13.2
# 1   bukhara  2023-01-21      0.3     -5.0  -2.3           0.3          -7.1
# 2   bukhara  2023-01-22      1.0     -3.6  -1.5           1.0          -6.4
# 3   bukhara  2023-01-23      1.2     -2.8  -1.0           1.2          -4.8
# 4   bukhara  2023-01-24      1.1     -2.6  -0.9          -1.0          -4.8
# 5   bukhara  2023-01-25      2.0     -2.4  -0.5           0.2          -6.6
# 6   bukhara  2023-01-26      1.9     -2.6  -0.7           1.9          -6.7
# 7   bukhara  2023-01-27      2.6     -2.1  -0.1           2.6          -6.0
# 8   bukhara  2023-01-28      2.9     -0.9   0.5           1.2          -4.0
# 9   bukhara  2023-01-29      4.1     -0.4   1.6           3.0          -1.2
# 10  bukhara  2023-01-30      8.2      0.8   4.2           5.7          -3.2
# ...

# %%
df.shape
# Out:
# (15, 33)

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 15

# %%
columns
# Out:
# 33

# %%
df.head()
# Out:
#       name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  bukhara  2023-01-20      3.9    -10.1  -4.2           3.9         -13.2
# 1  bukhara  2023-01-21      0.3     -5.0  -2.3           0.3          -7.1
# 2  bukhara  2023-01-22      1.0     -3.6  -1.5           1.0          -6.4
# 3  bukhara  2023-01-23      1.2     -2.8  -1.0           1.2          -4.8
# 4  bukhara  2023-01-24      1.1     -2.6  -0.9          -1.0          -4.8
#
#    feelslike  dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 0       -5.5 -8.6      73.7  ...          8.8        4          10
# 1       -3.5 -6.4      73.8  ...         11.0        5          10
# 2       -2.9 -7.1      66.2  ...         10.5        5          10
# 3       -1.7 -7.6      61.4  ...         11.2        5          10
# 4       -2.5 -9.1      54.0  ...         10.6        5          10
#
#                sunrise               sunset  moonphase        conditions  \
# ...

# %%
df.tail()
# Out:
#        name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 10  bukhara  2023-01-30      8.2      0.8   4.2           5.7          -3.2
# 11  bukhara  2023-01-31     11.3      4.1   7.2          11.3           0.5
# 12  bukhara  2023-02-01     11.9      5.3   8.2          11.9           2.2
# 13  bukhara  2023-02-02     16.6      5.9  10.8          16.6           2.8
# 14  bukhara  2023-02-03     13.8     11.2  12.7          13.8          11.2
#
#     feelslike  dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 10        1.1 -7.1      44.3  ...         12.3        5          10
# 11        4.8 -6.0      39.7  ...         10.7        5          10
# 12        6.4 -2.6      46.8  ...          8.4        3          10
# 13        9.4  1.5      54.7  ...          9.3        5          10
# 14       12.7  2.9      51.8  ...          2.6        1          10
#
#                 sunrise               sunset  moonphase        conditions  \
# ...

# %%
df[2:5]
# Out:
#       name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 2  bukhara  2023-01-22      1.0     -3.6  -1.5           1.0          -6.4
# 3  bukhara  2023-01-23      1.2     -2.8  -1.0           1.2          -4.8
# 4  bukhara  2023-01-24      1.1     -2.6  -0.9          -1.0          -4.8
#
#    feelslike  dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 2       -2.9 -7.1      66.2  ...         10.5        5          10
# 3       -1.7 -7.6      61.4  ...         11.2        5          10
# 4       -2.5 -9.1      54.0  ...         10.6        5          10
#
#                sunrise               sunset  moonphase        conditions  \
# 2  2023-01-22T07:58:35  2023-01-22T17:49:25       0.00  Partially cloudy
# 3  2023-01-23T07:57:58  2023-01-23T17:50:35       0.02  Partially cloudy
# 4  2023-01-24T07:57:18  2023-01-24T17:51:46       0.05  Partially cloudy
#
#                          description               icon  stations
# ...

# %%
df.columns
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations'],
#       dtype='object')

# %%
df.name
# Out:
# 0     bukhara
# 1     bukhara
# 2     bukhara
# 3     bukhara
# 4     bukhara
# 5     bukhara
# 6     bukhara
# 7     bukhara
# 8     bukhara
# 9     bukhara
# 10    bukhara
# 11    bukhara
# 12    bukhara
# 13    bukhara
# 14    bukhara
# Name: name, dtype: object

# %%
type(df.name)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#        name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0   bukhara  2023-01-20      3.9    -10.1  -4.2           3.9         -13.2
# 1   bukhara  2023-01-21      0.3     -5.0  -2.3           0.3          -7.1
# 2   bukhara  2023-01-22      1.0     -3.6  -1.5           1.0          -6.4
# 3   bukhara  2023-01-23      1.2     -2.8  -1.0           1.2          -4.8
# 4   bukhara  2023-01-24      1.1     -2.6  -0.9          -1.0          -4.8
# 5   bukhara  2023-01-25      2.0     -2.4  -0.5           0.2          -6.6
# 6   bukhara  2023-01-26      1.9     -2.6  -0.7           1.9          -6.7
# 7   bukhara  2023-01-27      2.6     -2.1  -0.1           2.6          -6.0
# 8   bukhara  2023-01-28      2.9     -0.9   0.5           1.2          -4.0
# 9   bukhara  2023-01-29      4.1     -0.4   1.6           3.0          -1.2
# 10  bukhara  2023-01-30      8.2      0.8   4.2           5.7          -3.2
# ...

# %%
df['feelslikemax'].max()
# Out:
# 16.6

# %%
df['feelslikemax'].min()
# Out:
# -1.0

# %%
df['feelslikemax'].mean()
# Out:
# 4.906666666666667

# %%
df['feelslikemax'].std()
# Out:
# 5.6457906781027924

# %%
df.describe()
# Out:
#          tempmax    tempmin       temp  feelslikemax  feelslikemin  feelslike  \
# count  15.000000  15.000000  15.000000     15.000000     15.000000  15.000000
# mean    5.520000  -0.346667   2.266667      4.906667     -3.153333   0.640000
# std     5.372044   5.185538   5.127888      5.645791      5.688568   5.311013
# min     0.300000 -10.100000  -4.200000     -1.000000    -13.200000  -5.500000
# 25%     1.550000  -2.700000  -0.950000      1.100000     -6.500000  -2.850000
# 50%     2.900000  -2.100000  -0.100000      2.600000     -4.800000  -1.700000
# 75%     9.750000   2.450000   5.700000      8.500000     -0.350000   2.950000
# max    16.600000  11.200000  12.700000     16.600000     11.200000  12.700000
#
#              dew   humidity     precip  precipprob  ...  windspeed  \
# count  15.000000  15.000000  15.000000   15.000000  ...  15.000000
# mean   -6.006667  56.166667   0.106667    5.393333  ...  14.353333
# ...

# %%
df[df.temp>5]
# Out:
#        name    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 11  bukhara  2023-01-31     11.3      4.1   7.2          11.3           0.5
# 12  bukhara  2023-02-01     11.9      5.3   8.2          11.9           2.2
# 13  bukhara  2023-02-02     16.6      5.9  10.8          16.6           2.8
# 14  bukhara  2023-02-03     13.8     11.2  12.7          13.8          11.2
#
#     feelslike  dew  humidity  ...  solarenergy  uvindex  severerisk  \
# 11        4.8 -6.0      39.7  ...         10.7        5          10
# 12        6.4 -2.6      46.8  ...          8.4        3          10
# 13        9.4  1.5      54.7  ...          9.3        5          10
# 14       12.7  2.9      51.8  ...          2.6        1          10
#
#                 sunrise               sunset  moonphase        conditions  \
# 11  2023-01-31T07:51:50  2023-01-31T18:00:05       0.39  Partially cloudy
# 12  2023-02-01T07:50:56  2023-02-01T18:01:17       0.42  Partially cloudy
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=15, step=1)

# %%
df.set_index('humidity', inplace=True)

# %%
df
# Out:
#              name    datetime  tempmax  tempmin  temp  feelslikemax  \
# humidity
# 73.7      bukhara  2023-01-20      3.9    -10.1  -4.2           3.9
# 73.8      bukhara  2023-01-21      0.3     -5.0  -2.3           0.3
# 66.2      bukhara  2023-01-22      1.0     -3.6  -1.5           1.0
# 61.4      bukhara  2023-01-23      1.2     -2.8  -1.0           1.2
# 54.0      bukhara  2023-01-24      1.1     -2.6  -0.9          -1.0
# 55.3      bukhara  2023-01-25      2.0     -2.4  -0.5           0.2
# 61.9      bukhara  2023-01-26      1.9     -2.6  -0.7           1.9
# 60.2      bukhara  2023-01-27      2.6     -2.1  -0.1           2.6
# 52.5      bukhara  2023-01-28      2.9     -0.9   0.5           1.2
# 46.2      bukhara  2023-01-29      4.1     -0.4   1.6           3.0
# 44.3      bukhara  2023-01-30      8.2      0.8   4.2           5.7
# 39.7      bukhara  2023-01-31     11.3      4.1   7.2          11.3
# 46.8      bukhara  2023-02-01     11.9      5.3   8.2          11.9
# ...

# %%
df.loc[51.8]
# Out:
# name                                         bukhara
# datetime                                  2023-02-03
# tempmax                                         13.8
# tempmin                                         11.2
# temp                                            12.7
# feelslikemax                                    13.8
# feelslikemin                                    11.2
# feelslike                                       12.7
# dew                                              2.9
# precip                                           1.1
# precipprob                                      19.0
# precipcover                                     8.33
# preciptype                                      rain
# snow                                               0
# snowdepth                                        0.0
# windgust                                        63.4
# windspeed                                       29.2
# winddir                                        155.8
# ...

# %%
df.reset_index(inplace=True) #To reset the indexing

# %%
df
# Out:
#     humidity     name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0       73.7  bukhara  2023-01-20      3.9    -10.1  -4.2           3.9
# 1       73.8  bukhara  2023-01-21      0.3     -5.0  -2.3           0.3
# 2       66.2  bukhara  2023-01-22      1.0     -3.6  -1.5           1.0
# 3       61.4  bukhara  2023-01-23      1.2     -2.8  -1.0           1.2
# 4       54.0  bukhara  2023-01-24      1.1     -2.6  -0.9          -1.0
# 5       55.3  bukhara  2023-01-25      2.0     -2.4  -0.5           0.2
# 6       61.9  bukhara  2023-01-26      1.9     -2.6  -0.7           1.9
# 7       60.2  bukhara  2023-01-27      2.6     -2.1  -0.1           2.6
# 8       52.5  bukhara  2023-01-28      2.9     -0.9   0.5           1.2
# 9       46.2  bukhara  2023-01-29      4.1     -0.4   1.6           3.0
# 10      44.3  bukhara  2023-01-30      8.2      0.8   4.2           5.7
# 11      39.7  bukhara  2023-01-31     11.3      4.1   7.2          11.3
# ...
